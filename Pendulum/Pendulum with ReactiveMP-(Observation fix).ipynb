# %% [markdown]
# # Single pendulum
#
#
# This notebook is an implementation of a controller for a single pendulum with REactiveMP.

# %%
using RxInfer, PyPlot, Compose
import ReactiveMP: getrecent, messageout

# %%
# Dynamical parameters
m = 0.65 # grams
l = 0.8 # cm
b = 0.6 # friction
G = 9.81 # gravity
O = [1.0; 0.0] # observation matrix

# Time step size
Δt = 0.1

# Transition matrix
A = [1 Δt; -G/l*Δt -b/(m*l^2)*Δt+1];

# Control matrix
B = reshape([0; 1/(m*l^2)*Δt], 2, 1);

# %%
# Internal dynamic model
function dzdt(s_t_min::AbstractVector, u::AbstractVector) # Transition function modeling transition due to gravity, friction and engine control
    s_t = A*s_t_min + B* u

    return s_t
end
# Out:
# dzdt (generic function with 1 method)

# %%
function initializeWorld()
    z_0 = [3.0, 0.0] # Initial position
    z_t_min = z_0
    function execute(a_t::Float64)
        z_t = dzdt(z_t, [a_t])
    
        z_t_min = z_t # Reset state
                
        return z_t
    end

    z_t = [1/3 *π, 0.0] # Predefine outcome variable
    observe() = z_t  # Report current position

    return (execute, observe)
end
# Out:
# initializeWorld (generic function with 1 method)

# %%
@model function pendulum(T)
    # Internal model perameters
    Gamma = 1e4*diageye(2) # Transition precision
    Theta = 1e-4*diageye(2) # Observation variance
    cA = constvar(A) # Transition matrix
    cB = constvar(B) # Control matrix
    cO = constvar(O) # Observation matrix
    
    m_s_t_min = datavar(Vector{Float64})
    V_s_t_min = datavar(Matrix{Float64})

    s_t_min ~ MvNormal(mean = m_s_t_min, cov = V_s_t_min)
    s_k_min = s_t_min
    
    m_u = datavar(Vector{Float64}, T)
    V_u = datavar(Matrix{Float64}, T)
    
    m_x = datavar(Vector{Float64}, T)
    V_x = datavar(Matrix{Float64}, T)
    
    u = randomvar(T)
    s = randomvar(T)
    x = randomvar(T)
    
    u_s = randomvar(T)
    
    for k in 1:T
        u[k] ~ MvNormal(mean = m_u[k], cov = V_u[k])
        u_s[k] ~ dzdt(s_k_min, u[k])
        s[k] ~ MvNormal(mean = u_s[k], precision = Gamma)
        x[k] ~ MvNormal(mean = dot(cO, s[k]), cov = Theta)
        x[k] ~ MvNormal(mean = m_x[k], cov = V_x[k]) # goal
        s_k_min = s[k]
    end
    
    return (s, )
end

@meta function pendulum_meta()
    dzdt() -> DeltaMeta(method = Linearization())
end
# Out:
# pendulum_meta (generic function with 1 method)

# %%
# Because states of the agent are unknown to the world, we wrap them in a comprehension.
# The comprehension only returns functions for interacting with the agent.
# Internal beliefs cannot be directly observed, and interaction is only allowed through the Markov blanket
function initializeAgent(; T = 5)
    Epsilon = fill(huge, 1, 1) # Control prior variance
    m_u = Vector{Float64}[ [ 0.0] for k=1:T ] # Set control priors
    V_u = Matrix{Float64}[ Epsilon for k=1:T ]

    x_target = [π, 0.0] # Goal state
    Sigma = 1e-4*diageye(2) # Goal prior variance
    m_x = [zeros(2) for k=1:T]
    m_x[end] = x_target
    V_x = [huge*diageye(2) for k=1:T]
    V_x[end] = Sigma # Set prior to reach goal at t=T

    m_s_t_min = [1/3 *π, 0.0] # Set initial brain state prior
    V_s_t_min = tiny*diageye(2)
    
    result = nothing

    # Initialize messages and marginals dictionary

    function infer(upsilon_t::Float64, y_hat_t::Vector{Float64})
        m_u[1] = [ upsilon_t ] # Register action with the generative model
        V_u[1] = fill(tiny, 1, 1) # Clamp control prior to performed action

        m_x[1] = y_hat_t # Register observation with the generative model
        V_x[1] = tiny*diageye(2) # Clamp goal prior to observation

        data = Dict(:m_u       => m_u, 
                    :V_u       => V_u, 
                    :m_x       => m_x, 
                    :V_x       => V_x,
                    :m_s_t_min => m_s_t_min,
                    :V_s_t_min => V_s_t_min)

        result = inference(
            model = pendulum(T),
            meta = pendulum_meta(),
            data = data,
        )
    end
    
    function act() 
        if result !== nothing
            return mode(result.posteriors[:u][2])[1]
        else
            return 0.0
        end
    end

    function slide(slide_msg_idx = 3)
        (s, ) = result.returnval
        (m_s_t_min, V_s_t_min) = mean_cov(getrecent(messageout(s[2], slide_msg_idx))) # Reset prior state statistics;

        m_u = circshift(m_u, -1)
        m_u[end] = [0.0]
        V_u = circshift(V_u, -1)
        V_u[end] = Epsilon

        m_x = circshift(m_x, -1)
        m_x[end] = x_target
        V_x = circshift(V_x, -1)
        V_x[end] = Sigma
    end

    return (infer, act, slide)    
end
# Out:
# initializeAgent (generic function with 1 method)

# %%
N = 80 # Total simulation time

(execute, observe)  = initializeWorld() # Let there be a world
(infer, act, slide) = initializeAgent(T = 3) # Let there be an agent

# Step through experimental protocol
a = Vector{Float64}(undef, N) # Actions
y = Vector{Vector{Float64}}(undef, N) # Observations
for t=1:N
    a[t] = act() # Evoke an action from the agent
           execute(a[t]) # The action influences hidden external states
    y[t] = observe() # Observe the current environmental outcome (update p)
           infer(a[t], y[t]) # Infer beliefs from current model state (update q)
           slide() # Prepare for next iteration
end
;
# Out:
# RuleMethodError: no method matching rule for the given arguments
#
# Possible fix, define:
#
# @rule typeof(dot)(:in2, Marginalisation) (m_out::MvNormalMeanCovariance, m_in1::PointMass, meta::TinyCorrection) = begin
#     return ...
# end
#
#
#
# Stacktrace:
#   [1] rule(fform::Function, on::Type, vconstraint::Marginalisation, mnames::Type, messages::Tuple{Message{MvNormalMeanCovariance{Float64, Vector{Float64}, Matrix{Float64}}}, Message{PointMass{Vector{Float64}}}}, qnames::Nothing, marginals::Nothing, meta::TinyCorrection, __node::ReactiveMP.FactorNode{typeof(dot), Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64, Int64, Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal}}, TinyCorrection, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}})
#     @ ReactiveMP C:\Users\adami\.julia\dev\ReactiveMP\src\rule.jl:774
#   [2] materialize!(mapping::ReactiveMP.MessageMapping{typeof(dot), DataType, Marginalisation, DataType, Nothing, TinyCorrection, ReactiveMP.FactorNode{typeof(dot), Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64, Int64, Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal}}, TinyCorrection, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}, dependencies::Tuple{Tuple{Message{MvNormalMeanCovariance{Float64, Vector{Float64}, Matrix{Float64}}}, Message{PointMass{Vector{Float64}}}}, Nothing})
#     @ ReactiveMP C:\Users\adami\.julia\dev\ReactiveMP\src\message.jl:280
#   [3] materialize!(vmessage::VariationalMessage{Tuple{ReactiveMP.MessageObservable{Message}, SingleObservable{Message{PointMass{Vector{Float64}}}, AsapScheduler}}, Nothing, ReactiveMP.MessageMapping{typeof(dot), DataType, Marginalisation, DataType, Nothing, TinyCorrection, ReactiveMP.FactorNode{typeof(dot), Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64, Int64, Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal}}, TinyCorrection, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}})
#     @ ReactiveMP C:\Users\adami\.julia\dev\ReactiveMP\src\message.jl:198
#   [4] as_message(vmessage::VariationalMessage{Tuple{ReactiveMP.MessageObservable{Message}, SingleObservable{Message{PointMass{Vector{Float64}}}, AsapScheduler}}, Nothing, ReactiveMP.MessageMapping{typeof(dot), DataType, Marginalisation, DataType, Nothing, TinyCorrection, ReactiveMP.FactorNode{typeof(dot), Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64, Int64, Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal}}, TinyCorrection, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}})
#     @ ReactiveMP C:\Users\adami\.julia\dev\ReactiveMP\src\message.jl:206
#   [5] MappingRF
#     @ .\reduce.jl:95 [inlined]
#   [6] _foldl_impl(op::Base.MappingRF{typeof(as_message), Base.BottomRF{ReactiveMP.var"#26#28"{ProdAnalytical}}}, init::Base._InitialValue, itr::Vector{AbstractMessage})
#     @ Base .\reduce.jl:62
#   [7] foldl_impl
#     @ .\reduce.jl:48 [inlined]
#   [8] mapfoldl_impl
#     @ .\reduce.jl:44 [inlined]
#   [9] #mapfoldl#244
#     @ .\reduce.jl:162 [inlined]
#  [10] mapfoldl
#     @ .\reduce.jl:162 [inlined]
#  [11] #foldl#245
#     @ .\reduce.jl:180 [inlined]
#  [12] foldl
#     @ .\reduce.jl:180 [inlined]
#  [13] (::ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint})(messages::Vector{AbstractMessage})
#     @ ReactiveMP C:\Users\adami\.julia\dev\ReactiveMP\src\message.jl:131
#  [14] next_received!(wrapper::Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}, data::VariationalMessage{Tuple{ReactiveMP.MessageObservable{Message}, SingleObservable{Message{PointMass{Vector{Float64}}}, AsapScheduler}}, Nothing, ReactiveMP.MessageMapping{typeof(dot), DataType, Marginalisation, DataType, Nothing, TinyCorrection, ReactiveMP.FactorNode{typeof(dot), Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64, Int64, Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal}}, TinyCorrection, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}}, index::CartesianIndex{1})
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\collected.jl:97
#  [15] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\collected.jl:87 [inlined]
#  [16] scheduled_next!(actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}, value::VariationalMessage{Tuple{ReactiveMP.MessageObservable{Message}, SingleObservable{Message{PointMass{Vector{Float64}}}, AsapScheduler}}, Nothing, ReactiveMP.MessageMapping{typeof(dot), DataType, Marginalisation, DataType, Nothing, TinyCorrection, ReactiveMP.FactorNode{typeof(dot), Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64, Int64, Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal}}, TinyCorrection, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}}, #unused#::AsapScheduler)
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\schedulers\asap.jl:23
#  [17] on_next!(subject::Subject{AbstractMessage, AsapScheduler, AsapScheduler}, data::VariationalMessage{Tuple{ReactiveMP.MessageObservable{Message}, SingleObservable{Message{PointMass{Vector{Float64}}}, AsapScheduler}}, Nothing, ReactiveMP.MessageMapping{typeof(dot), DataType, Marginalisation, DataType, Nothing, TinyCorrection, ReactiveMP.FactorNode{typeof(dot), Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64, Int64, Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal}}, TinyCorrection, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}})
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\subjects\subject.jl:62
#  [18] actor_on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:250 [inlined]
#  [19] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:202 [inlined]
#  [20] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\subjects\recent.jl:62 [inlined]
#  [21] actor_on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:250 [inlined]
#  [22] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:202 [inlined]
#  [23] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\operators\map.jl:60 [inlined]
#  [24] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:206 [inlined]
#  [25] next_received!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\combined.jl:101 [inlined]
#  [26] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\combined.jl:68 [inlined]
#  [27] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:206 [inlined]
#  [28] next_received!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\combined_updates.jl:65 [inlined]
#  [29] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\combined_updates.jl:34 [inlined]
#  [30] scheduled_next!(actor::Rocket.CombineLatestUpdatesInnerActor{Message, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.MessageObservable{Message}, SingleObservable{Message{PointMass{Vector{Float64}}}, AsapScheduler}}, Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.MessageObservable{Message}, SingleObservable{Message{PointMass{Vector{Float64}}}, AsapScheduler}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Tuple{ReactiveMP.MessageObservable{Message}, SingleObservable{Message{PointMass{Vector{Float64}}}, AsapScheduler}}, Nothing}, Rocket.MapActor{Tuple{Tuple{ReactiveMP.MessageObservable{Message}, SingleObservable{Message{PointMass{Vector{Float64}}}, AsapScheduler}}, Nothing}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#281#282"{ReactiveMP.MessageMapping{typeof(dot), DataType, Marginalisation, DataType, Nothing, TinyCorrection, ReactiveMP.FactorNode{typeof(dot), Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64, Int64, Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal}}, TinyCorrection, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}}, value::Message{MvNormalMeanCovariance{Float64, Vector{Float64}, Matrix{Float64}}}, #unused#::AsapScheduler)
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\schedulers\asap.jl:23
#  [31] on_next!(subject::Subject{Message, AsapScheduler, AsapScheduler}, data::Message{MvNormalMeanCovariance{Float64, Vector{Float64}, Matrix{Float64}}})
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\subjects\subject.jl:62
#  [32] actor_on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:250 [inlined]
#  [33] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:202 [inlined]
#  [34] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\subjects\recent.jl:62 [inlined]
#  [35] actor_on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:250 [inlined]
#  [36] next!(actor::Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, data::Message{MvNormalMeanCovariance{Float64, Vector{Float64}, Matrix{Float64}}})
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:202
# --- the last 23 lines are repeated 1 more time ---
#  [60] next_received!(wrapper::Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}, data::VariationalMessage{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Vector{Float64}}}, Subject{Message{PointMass{Vector{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Vector{Float64}}}, typeof(as_marginal)}}, ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Matrix{Float64}}}, Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Matrix{Float64}}}, typeof(as_marginal)}}}, ReactiveMP.MessageMapping{MvNormalMeanCovariance, DataType, Marginalisation, Nothing, DataType, Nothing, ReactiveMP.FactorNode{Type{MvNormalMeanCovariance}, Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64}, Tuple{Int64}, Tuple{Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, Nothing, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}}, index::CartesianIndex{1})
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\collected.jl:97
#  [61] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\collected.jl:87 [inlined]
#  [62] scheduled_next!(actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}, value::VariationalMessage{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Vector{Float64}}}, Subject{Message{PointMass{Vector{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Vector{Float64}}}, typeof(as_marginal)}}, ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Matrix{Float64}}}, Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Matrix{Float64}}}, typeof(as_marginal)}}}, ReactiveMP.MessageMapping{MvNormalMeanCovariance, DataType, Marginalisation, Nothing, DataType, Nothing, ReactiveMP.FactorNode{Type{MvNormalMeanCovariance}, Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64}, Tuple{Int64}, Tuple{Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, Nothing, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}}, #unused#::AsapScheduler)
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\schedulers\asap.jl:23
#  [63] on_next!(subject::Subject{AbstractMessage, AsapScheduler, AsapScheduler}, data::VariationalMessage{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Vector{Float64}}}, Subject{Message{PointMass{Vector{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Vector{Float64}}}, typeof(as_marginal)}}, ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Matrix{Float64}}}, Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Matrix{Float64}}}, typeof(as_marginal)}}}, ReactiveMP.MessageMapping{MvNormalMeanCovariance, DataType, Marginalisation, Nothing, DataType, Nothing, ReactiveMP.FactorNode{Type{MvNormalMeanCovariance}, Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64}, Tuple{Int64}, Tuple{Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, Nothing, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}})
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\subjects\subject.jl:62
#  [64] actor_on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:250 [inlined]
#  [65] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:202 [inlined]
#  [66] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\subjects\recent.jl:62 [inlined]
#  [67] actor_on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:250 [inlined]
#  [68] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:202 [inlined]
#  [69] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\operators\map.jl:60 [inlined]
#  [70] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:206 [inlined]
#  [71] next_received!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\combined.jl:101 [inlined]
#  [72] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\combined.jl:68 [inlined]
#  [73] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:206 [inlined]
#  [74] next_received!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\combined_updates.jl:65 [inlined]
#  [75] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\observable\combined_updates.jl:34 [inlined]
#  [76] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:206 [inlined]
#  [77] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\operators\map.jl:60 [inlined]
#  [78] scheduled_next!(actor::Rocket.MapActor{Message{PointMass{Matrix{Float64}}}, Rocket.CombineLatestUpdatesInnerActor{Marginal, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Vector{Float64}}}, Subject{Message{PointMass{Vector{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Vector{Float64}}}, typeof(as_marginal)}}, ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Matrix{Float64}}}, Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Matrix{Float64}}}, typeof(as_marginal)}}}, Rocket.CombineLatestInnerActor{Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Vector{Float64}}}, Subject{Message{PointMass{Vector{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Vector{Float64}}}, typeof(as_marginal)}}, ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Matrix{Float64}}}, Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Matrix{Float64}}}, typeof(as_marginal)}}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Vector{Float64}}}, Subject{Message{PointMass{Vector{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Vector{Float64}}}, typeof(as_marginal)}}, ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Matrix{Float64}}}, Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Matrix{Float64}}}, typeof(as_marginal)}}}}, Rocket.MapActor{Tuple{Nothing, Tuple{ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Vector{Float64}}}, Subject{Message{PointMass{Vector{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Vector{Float64}}}, typeof(as_marginal)}}, ProxyObservable{Marginal, Rocket.RecentSubjectInstance{Message{PointMass{Matrix{Float64}}}, Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}}, Rocket.MapProxy{Message{PointMass{Matrix{Float64}}}, typeof(as_marginal)}}}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#281#282"{ReactiveMP.MessageMapping{MvNormalMeanCovariance, DataType, Marginalisation, Nothing, DataType, Nothing, ReactiveMP.FactorNode{Type{MvNormalMeanCovariance}, Tuple{ReactiveMP.NodeInterface, ReactiveMP.NodeInterface, ReactiveMP.NodeInterface}, Tuple{Tuple{Int64}, Tuple{Int64}, Tuple{Int64}}, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, Nothing, ReactiveMP.FactorNodePipeline{ReactiveMP.DefaultFunctionalDependencies, EmptyPipelineStage}}}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}}, typeof(as_marginal)}, value::Message{PointMass{Matrix{Float64}}}, #unused#::AsapScheduler)
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\schedulers\asap.jl:23
#  [79] on_next!(subject::Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}, data::Message{PointMass{Matrix{Float64}}})
#     @ Rocket C:\Users\adami\.julia\packages\Rocket\YvAn4\src\subjects\subject.jl:62
#  [80] actor_on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:250 [inlined]
#  [81] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:202 [inlined]
#  [82] on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\subjects\recent.jl:62 [inlined]
#  [83] actor_on_next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:250 [inlined]
#  [84] next!
#     @ C:\Users\adami\.julia\packages\Rocket\YvAn4\src\actor.jl:202 [inlined]
#  [85] update!
#     @ C:\Users\adami\.julia\dev\ReactiveMP\src\variables\data.jl:138 [inlined]
#  [86] update!
#     @ C:\Users\adami\.julia\dev\ReactiveMP\src\variables\data.jl:115 [inlined]
#  [87] #207
#     @ C:\Users\adami\.julia\dev\ReactiveMP\src\variables\data.jl:147 [inlined]
#  [88] foreach(f::ReactiveMP.var"#207#208", itr::Base.Iterators.Zip{Tuple{Vector{DataVariable{PointMass{Matrix{Float64}}, Rocket.RecentSubjectInstance{Message{PointMass{Matrix{Float64}}}, Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}}}}, Vector{Matrix{Float64}}}})
#     @ Base .\abstractarray.jl:2712
#  [89] update!(datavars::Vector{DataVariable{PointMass{Matrix{Float64}}, Rocket.RecentSubjectInstance{Message{PointMass{Matrix{Float64}}}, Subject{Message{PointMass{Matrix{Float64}}}, AsapScheduler, AsapScheduler}}}}, data::Vector{Matrix{Float64}})
#     @ ReactiveMP C:\Users\adami\.julia\dev\ReactiveMP\src\variables\data.jl:146
#  [90] inference(; model::RxInfer.ModelGenerator{var"###pendulum#300", Tuple{Int64}, NamedTuple{(), Tuple{}}}, data::Dict{Symbol, Array}, initmarginals::Nothing, initmessages::Nothing, constraints::Nothing, meta::MetaSpecification{Tuple{ReactiveMP.MetaSpecificationEntry{0, DeltaMeta{Linearization, Nothing}}}}, options::Nothing, returnvars::Nothing, iterations::Nothing, free_energy::Bool, free_energy_diagnostics::Tuple{BetheFreeEnergyCheckNaNs, BetheFreeEnergyCheckInfs}, showprogress::Bool, callbacks::Nothing, warn::Bool)
#     @ RxInfer C:\Users\adami\.julia\packages\RxInfer\dsz2J\src\inference.jl:511
#  [91] (::var"#infer#8"{Int64})(upsilon_t::Float64, y_hat_t::Vector{Float64})
#     @ Main .\In[6]:37
#  [92] top-level scope
#     @ .\In[7]:13
#  [93] eval
#     @ .\boot.jl:373 [inlined]

# %%
# Ploting the motion of the pendulum
function draw_pendulum(t)
    IJulia.clear_output(true)
    sleep(0.05)
    x = 0.5 +l*sin(t)
    y = l*cos(t)
    display(compose(context(units=UnitBox(-1,-1, 3,3)),
            (context(), line([(0,0), (1,0)]), stroke("black"),linewidth(1mm)),
            (context(),line([(0.5,0.0),(x,y)]), stroke("black"), linewidth(0.5mm)),
            (context(),circle(x, y, m* 0.08),fill("blue")))
        )
        
end
precompile(draw_pendulum, (Float64, ))
positions = mapreduce(permutedims, vcat, y)
source = from(positions[:,1])
subscription = subscribe!(source, draw_pendulum)
# Out:
# UndefRefError: access to undefined reference
#
# Stacktrace:
#   [1] getindex
#     @ .\array.jl:861 [inlined]
#   [2] mapreduce_impl(f::typeof(permutedims), op::typeof(vcat), A::Vector{Vector{Float64}}, ifirst::Int64, ilast::Int64, blksize::Int64)
#     @ Base .\reduce.jl:243
#   [3] mapreduce_impl
#     @ .\reduce.jl:259 [inlined]
#   [4] _mapreduce(f::typeof(permutedims), op::typeof(vcat), #unused#::IndexLinear, A::Vector{Vector{Float64}})
#     @ Base .\reduce.jl:417
#   [5] _mapreduce_dim(f::Function, op::Function, #unused#::Base._InitialValue, A::Vector{Vector{Float64}}, #unused#::Colon)
#     @ Base .\reducedim.jl:330
#   [6] #mapreduce#731
#     @ .\reducedim.jl:322 [inlined]
#   [7] mapreduce(f::Function, op::Function, A::Vector{Vector{Float64}})
#     @ Base .\reducedim.jl:322
#   [8] top-level scope
#     @ In[8]:15
#   [9] eval
#     @ .\boot.jl:373 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1196
